# %%
import pandas as pd
import numpy as np 
import matplotlib.pyplot as plt 
import seaborn as sns

# %%
data=  pd.read_csv("housing.csv")
data
# Out:
#        longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 0        -122.23     37.88                41.0        880.0           129.0
# 1        -122.22     37.86                21.0       7099.0          1106.0
# 2        -122.24     37.85                52.0       1467.0           190.0
# 3        -122.25     37.85                52.0       1274.0           235.0
# 4        -122.25     37.85                52.0       1627.0           280.0
# ...          ...       ...                 ...          ...             ...
# 20635    -121.09     39.48                25.0       1665.0           374.0
# 20636    -121.21     39.49                18.0        697.0           150.0
# 20637    -121.22     39.43                17.0       2254.0           485.0
# 20638    -121.32     39.43                18.0       1860.0           409.0
# 20639    -121.24     39.37                16.0       2785.0           616.0
#
#        population  households  median_income  median_house_value  \
# 0           322.0       126.0         8.3252            452600.0
# 1          2401.0      1138.0         8.3014            358500.0
# 2           496.0       177.0         7.2574            352100.0
# 3           558.0       219.0         5.6431            341300.0
# 4           565.0       259.0         3.8462            342200.0
# ...           ...         ...            ...                 ...
# 20635       845.0       330.0         1.5603             78100.0
# 20636       356.0       114.0         2.5568             77100.0
# 20637      1007.0       433.0         1.7000             92300.0
# 20638       741.0       349.0         1.8672             84700.0
# 20639      1387.0       530.0         2.3886             89400.0
#
#       ocean_proximity
# 0            NEAR BAY
# 1            NEAR BAY
# 2            NEAR BAY
# 3            NEAR BAY
# 4            NEAR BAY
# ...               ...
# 20635          INLAND
# 20636          INLAND
# 20637          INLAND
# 20638          INLAND
# 20639          INLAND
#
# [20640 rows x 10 columns]

# %%
data
# Out:
#        longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 0        -122.23     37.88                41.0        880.0           129.0
# 1        -122.22     37.86                21.0       7099.0          1106.0
# 2        -122.24     37.85                52.0       1467.0           190.0
# 3        -122.25     37.85                52.0       1274.0           235.0
# 4        -122.25     37.85                52.0       1627.0           280.0
# ...          ...       ...                 ...          ...             ...
# 20635    -121.09     39.48                25.0       1665.0           374.0
# 20636    -121.21     39.49                18.0        697.0           150.0
# 20637    -121.22     39.43                17.0       2254.0           485.0
# 20638    -121.32     39.43                18.0       1860.0           409.0
# 20639    -121.24     39.37                16.0       2785.0           616.0
#
#        population  households  median_income  median_house_value  \
# 0           322.0       126.0         8.3252            452600.0
# 1          2401.0      1138.0         8.3014            358500.0
# 2           496.0       177.0         7.2574            352100.0
# 3           558.0       219.0         5.6431            341300.0
# 4           565.0       259.0         3.8462            342200.0
# ...           ...         ...            ...                 ...
# 20635       845.0       330.0         1.5603             78100.0
# 20636       356.0       114.0         2.5568             77100.0
# 20637      1007.0       433.0         1.7000             92300.0
# 20638       741.0       349.0         1.8672             84700.0
# 20639      1387.0       530.0         2.3886             89400.0
#
#       ocean_proximity
# 0            NEAR BAY
# 1            NEAR BAY
# 2            NEAR BAY
# 3            NEAR BAY
# 4            NEAR BAY
# ...               ...
# 20635          INLAND
# 20636          INLAND
# 20637          INLAND
# 20638          INLAND
# 20639          INLAND
#
# [20640 rows x 10 columns]

# %%
# data_shuffled = data.sample(n=len(data), random_state=1) 
# # data_shuffled

# %%
# pd.get_dummies(data_shuffled['ocean_proximity']).head()

# %%
# pd.get_dummies(data_shuffled['median_income']).head()

# %%
# data_shuffled.drop('ocean_proximity',axis=1).head()

# %%
# data_final= pd.concat([data_shuffled.drop('ocean_proximity',axis=1),
#                        pd.get_dummies(data_shuffled['ocean_proximity'])], axis=1 )
# data_final

# %%
# data_final = data_final[['latitude' ,
#                          'housing_median_age' , 'total_rooms',
#                          'total_bedrooms','population',
#                          'households', 'median_income',
#                          'ISLAND', 'NEAR BAY', 'NEAR OCEAN','median_house_value']]
# data_final

# %%
# Data Exploration

# %%
data.dropna(inplace=True)

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 20433 entries, 0 to 20639
# Data columns (total 10 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   longitude           20433 non-null  float64
#  1   latitude            20433 non-null  float64
#  2   housing_median_age  20433 non-null  float64
#  3   total_rooms         20433 non-null  float64
#  4   total_bedrooms      20433 non-null  float64
#  5   population          20433 non-null  float64
#  6   households          20433 non-null  float64
#  7   median_income       20433 non-null  float64
#  8   median_house_value  20433 non-null  float64
#  9   ocean_proximity     20433 non-null  object
# dtypes: float64(9), object(1)
# memory usage: 1.7+ MB

# %%
from sklearn.model_selection import train_test_split
X= data.drop(['median_house_value'],axis=1)
y=data['median_house_value']

# %%
X_train, X_test, y_train, y_test = train_test_split(X,y,test_size=0.2)

# %%
train_data=X_train.join(y_train)

# %%
train_data
# Out:
#        longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 11192    -117.93     33.82                28.0       2444.0           555.0
# 11522    -118.08     33.72                14.0       2021.0           396.0
# 5152     -118.26     33.95                38.0       1387.0           346.0
# 19777    -122.19     39.92                20.0       2563.0           658.0
# 11211    -117.91     33.82                32.0       2696.0           640.0
# ...          ...       ...                 ...          ...             ...
# 3807     -118.45     34.20                19.0       3666.0          1150.0
# 3314     -122.79     39.02                23.0        642.0           203.0
# 13522    -117.41     34.23                17.0        889.0           131.0
# 14529    -117.14     32.92                15.0       3242.0           595.0
# 6345     -117.75     34.05                27.0        437.0           108.0
#
#        population  households  median_income ocean_proximity  \
# 11192      1848.0       567.0         3.0179       <1H OCEAN
# 11522       696.0       367.0         7.1673      NEAR OCEAN
# 5152       1240.0       355.0         1.6898       <1H OCEAN
# 19777      1363.0       611.0         1.0230          INLAND
# 11211      2330.0       626.0         2.9479       <1H OCEAN
# ...           ...         ...            ...             ...
# 3807       2657.0      1090.0         2.9688       <1H OCEAN
# 3314        265.0        84.0         1.8833          INLAND
# 13522       439.0       141.0         6.1426          INLAND
# 14529      1936.0       593.0         4.9706       <1H OCEAN
# 6345        469.0        97.0         1.7206          INLAND
#
#        median_house_value
# 11192            198800.0
# 11522            340700.0
# 5152              95100.0
# 19777             54200.0
# 11211            184600.0
# ...                   ...
# 3807             202100.0
# 3314              96900.0
# 13522            155000.0
# 14529            184700.0
# 6345             107500.0
#
# [16346 rows x 10 columns]

# %%
train_data.hist(figsize=(16,9))
# Out:
# array([[<Axes: title={'center': 'longitude'}>,
#         <Axes: title={'center': 'latitude'}>,
#         <Axes: title={'center': 'housing_median_age'}>],
#        [<Axes: title={'center': 'total_rooms'}>,
#         <Axes: title={'center': 'total_bedrooms'}>,
#         <Axes: title={'center': 'population'}>],
#        [<Axes: title={'center': 'households'}>,
#         <Axes: title={'center': 'median_income'}>,
#         <Axes: title={'center': 'median_house_value'}>]], dtype=object)

# %%
numeric_data = train_data.select_dtypes(include='number')  # Select only numeric columns
correlation_matrix = numeric_data.corr()  # Compute correlation matrix
plt.figure(figsize=(15, 8))
sns.heatmap(correlation_matrix, annot=True, cmap="YlGnBu")
# Out:
# <Axes: >

# %%
train_data['total_rooms'] = np.log(train_data['total_rooms'] + 1)
train_data['total_bedrooms'] = np.log(train_data['total_bedrooms'] + 1)
train_data['population'] = np.log(train_data['population'] + 1)
train_data['households'] = np.log(train_data['households'] + 1)

# %%
train_data
# Out:
#        longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 11192    -117.93     33.82                28.0     7.801800        6.320768
# 11522    -118.08     33.72                14.0     7.611842        5.983936
# 5152     -118.26     33.95                38.0     7.235619        5.849325
# 19777    -122.19     39.92                20.0     7.849324        6.490724
# 11211    -117.91     33.82                32.0     7.899895        6.463029
# ...          ...       ...                 ...          ...             ...
# 3807     -118.45     34.20                19.0     8.207129        7.048386
# 3314     -122.79     39.02                23.0     6.466145        5.318120
# 13522    -117.41     34.23                17.0     6.791221        4.882802
# 14529    -117.14     32.92                15.0     8.084254        6.390241
# 6345     -117.75     34.05                27.0     6.082219        4.691348
#
#        population  households  median_income ocean_proximity  \
# 11192    7.522400    6.342121         3.0179       <1H OCEAN
# 11522    6.546785    5.908083         7.1673      NEAR OCEAN
# 5152     7.123673    5.874931         1.6898       <1H OCEAN
# 19777    7.218177    6.416732         1.0230          INLAND
# 11211    7.754053    6.440947         2.9479       <1H OCEAN
# ...           ...         ...            ...             ...
# 3807     7.885329    6.994850         2.9688       <1H OCEAN
# 3314     5.583496    4.442651         1.8833          INLAND
# 13522    6.086775    4.955827         6.1426          INLAND
# 14529    7.568896    6.386879         4.9706       <1H OCEAN
# 6345     6.152733    4.584967         1.7206          INLAND
#
#        median_house_value
# 11192            198800.0
# 11522            340700.0
# 5152              95100.0
# 19777             54200.0
# 11211            184600.0
# ...                   ...
# 3807             202100.0
# 3314              96900.0
# 13522            155000.0
# 14529            184700.0
# 6345             107500.0
#
# [16346 rows x 10 columns]

# %%
train_data.hist(figsize=(16,9))
# Out:
# array([[<Axes: title={'center': 'longitude'}>,
#         <Axes: title={'center': 'latitude'}>,
#         <Axes: title={'center': 'housing_median_age'}>],
#        [<Axes: title={'center': 'total_rooms'}>,
#         <Axes: title={'center': 'total_bedrooms'}>,
#         <Axes: title={'center': 'population'}>],
#        [<Axes: title={'center': 'households'}>,
#         <Axes: title={'center': 'median_income'}>,
#         <Axes: title={'center': 'median_house_value'}>]], dtype=object)

# %%
# Data preprocessing

# %%
# train_data.ocean_proximity.value_counts()
pd.get_dummies(train_data.ocean_proximity)
# Out:
#        <1H OCEAN  INLAND  ISLAND  NEAR BAY  NEAR OCEAN
# 11192       True   False   False     False       False
# 11522      False   False   False     False        True
# 5152        True   False   False     False       False
# 19777      False    True   False     False       False
# 11211       True   False   False     False       False
# ...          ...     ...     ...       ...         ...
# 3807        True   False   False     False       False
# 3314       False    True   False     False       False
# 13522      False    True   False     False       False
# 14529       True   False   False     False       False
# 6345       False    True   False     False       False
#
# [16346 rows x 5 columns]

# %%
train_data=train_data.join(pd.get_dummies(train_data.ocean_proximity)).drop(['ocean_proximity'],axis=1)

# %%
plt.figure(figsize=(15,8))
sns.heatmap(train_data.corr(), annot=True, cmap="YlGnBu")
# Out:
# <Axes: >

# %%
# USE FEATURE ENGINEERING

# %%
plt.figure(figsize=(16,9))
sns.scatterplot(x="latitude" , y="longitude", data=train_data, hue="median_house_value", palette="coolwarm")
# Out:
# <Axes: xlabel='latitude', ylabel='longitude'>

# %%
train_data
# Out:
#        longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 11192    -117.93     33.82                28.0     7.801800        6.320768
# 11522    -118.08     33.72                14.0     7.611842        5.983936
# 5152     -118.26     33.95                38.0     7.235619        5.849325
# 19777    -122.19     39.92                20.0     7.849324        6.490724
# 11211    -117.91     33.82                32.0     7.899895        6.463029
# ...          ...       ...                 ...          ...             ...
# 3807     -118.45     34.20                19.0     8.207129        7.048386
# 3314     -122.79     39.02                23.0     6.466145        5.318120
# 13522    -117.41     34.23                17.0     6.791221        4.882802
# 14529    -117.14     32.92                15.0     8.084254        6.390241
# 6345     -117.75     34.05                27.0     6.082219        4.691348
#
#        population  households  median_income  median_house_value  <1H OCEAN  \
# 11192    7.522400    6.342121         3.0179            198800.0       True
# 11522    6.546785    5.908083         7.1673            340700.0      False
# 5152     7.123673    5.874931         1.6898             95100.0       True
# 19777    7.218177    6.416732         1.0230             54200.0      False
# 11211    7.754053    6.440947         2.9479            184600.0       True
# ...           ...         ...            ...                 ...        ...
# 3807     7.885329    6.994850         2.9688            202100.0       True
# 3314     5.583496    4.442651         1.8833             96900.0      False
# 13522    6.086775    4.955827         6.1426            155000.0      False
# 14529    7.568896    6.386879         4.9706            184700.0       True
# 6345     6.152733    4.584967         1.7206            107500.0      False
#
#        INLAND  ISLAND  NEAR BAY  NEAR OCEAN
# 11192   False   False     False       False
# 11522   False   False     False        True
# 5152    False   False     False       False
# 19777    True   False     False       False
# 11211   False   False     False       False
# ...       ...     ...       ...         ...
# 3807    False   False     False       False
# 3314     True   False     False       False
# 13522    True   False     False       False
# 14529   False   False     False       False
# 6345     True   False     False       False
#
# [16346 rows x 14 columns]

# %%
train_data['bedroom_ratio'] = train_data['total_bedrooms']/ train_data['total_rooms']
train_data['household_rooms'] = train_data['total_bedrooms']/ train_data['households']

# %%
plt.figure(figsize=(16,9))
sns.scatterplot(x="latitude" , y="longitude", data=train_data, hue="median_house_value", palette="coolwarm")
# Out:
# <Axes: xlabel='latitude', ylabel='longitude'>

# %%
plt.figure(figsize=(15,8))
sns.heatmap(train_data.corr(), annot=True, cmap="YlGnBu")
# Out:
# <Axes: >

# %%
# Use LinearRegression

# %%
from sklearn.linear_model import LinearRegression
from sklearn.preprocessing import StandardScaler
scaler =StandardScaler()
X_train, y_train = train_data.drop(['median_house_value'],axis=1) , train_data['median_house_value']
X_train_s = scaler.fit_transform(X_train)
reg = LinearRegression()
reg.fit(X_train_s, y_train)
# Out:
# LinearRegression()

# %%
test_data= X_test.join(y_test)

test_data['total_rooms'] = np.log(test_data['total_rooms'] + 1)
test_data['total_bedrooms'] = np.log(test_data['total_bedrooms'] + 1)
test_data['population'] = np.log(test_data['population'] + 1)
test_data['households'] = np.log(test_data['households'] + 1)

# %%
test_data=test_data.join(pd.get_dummies(test_data.ocean_proximity)).drop(['ocean_proximity'], axis=1)

# %%
test_data['bedroom_ratio'] = test_data['total_bedrooms']/ test_data['total_rooms']
test_data['household_rooms'] = test_data['total_bedrooms']/ test_data['households']

# %%
X_test, y_test = test_data.drop(['median_house_value'],axis=1) ,  test_data['median_house_value']

# %%
X_test_s= scaler.transform(X_test)

# %%
train_data
# Out:
#        longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 11192    -117.93     33.82                28.0     7.801800        6.320768
# 11522    -118.08     33.72                14.0     7.611842        5.983936
# 5152     -118.26     33.95                38.0     7.235619        5.849325
# 19777    -122.19     39.92                20.0     7.849324        6.490724
# 11211    -117.91     33.82                32.0     7.899895        6.463029
# ...          ...       ...                 ...          ...             ...
# 3807     -118.45     34.20                19.0     8.207129        7.048386
# 3314     -122.79     39.02                23.0     6.466145        5.318120
# 13522    -117.41     34.23                17.0     6.791221        4.882802
# 14529    -117.14     32.92                15.0     8.084254        6.390241
# 6345     -117.75     34.05                27.0     6.082219        4.691348
#
#        population  households  median_income  median_house_value  <1H OCEAN  \
# 11192    7.522400    6.342121         3.0179            198800.0       True
# 11522    6.546785    5.908083         7.1673            340700.0      False
# 5152     7.123673    5.874931         1.6898             95100.0       True
# 19777    7.218177    6.416732         1.0230             54200.0      False
# 11211    7.754053    6.440947         2.9479            184600.0       True
# ...           ...         ...            ...                 ...        ...
# 3807     7.885329    6.994850         2.9688            202100.0       True
# 3314     5.583496    4.442651         1.8833             96900.0      False
# 13522    6.086775    4.955827         6.1426            155000.0      False
# 14529    7.568896    6.386879         4.9706            184700.0       True
# 6345     6.152733    4.584967         1.7206            107500.0      False
#
#        INLAND  ISLAND  NEAR BAY  NEAR OCEAN  bedroom_ratio  household_rooms
# 11192   False   False     False       False       0.810168         0.996633
# 11522   False   False     False        True       0.786135         1.012839
# 5152    False   False     False       False       0.808407         0.995641
# 19777    True   False     False       False       0.826915         1.011531
# 11211   False   False     False       False       0.818116         1.003429
# ...       ...     ...       ...         ...            ...              ...
# 3807    False   False     False       False       0.858813         1.007654
# 3314     True   False     False       False       0.822456         1.197060
# 13522    True   False     False       False       0.718987         0.985265
# 14529   False   False     False       False       0.790455         1.000526
# 6345     True   False     False       False       0.771322         1.023202
#
# [16346 rows x 16 columns]

# %%
reg.score(X_test_s, y_test)
# Out:
# 0.6748273817082482

# %%
reg.score(X_train_s, y_train)
# Out:
# 0.6701724789136202

# %%
from sklearn.ensemble import RandomForestRegressor

forest = RandomForestRegressor() 

forest.fit(X_train_s, y_train)

# %%
forest.score(X_test_s,y_test)
# Out:
# 0.8247593087923877

# %%
from sklearn.model_selection import GridSearchCV

forest = RandomForestRegressor()

param_grid = {
    "n_estimators": [100, 200, 300],
    "min_samples_split": [2, 4],
    "max_depth": [None, 4, 8]
}

# %%
reg.fit(X_train,y_train)
# Out:
# LinearRegression()

# %%
grid_search = GridSearchCV(forest, param_grid, cv=5,
                            scoring="neg_mean_squared_error",
                            return_train_score=True)
grid_search.fit(X_train_s, y_train)
# Out:
# GridSearchCV(cv=5, estimator=RandomForestRegressor(),
#              param_grid={'max_depth': [None, 4, 8], 'min_samples_split': [2, 4],
#                          'n_estimators': [100, 200, 300]},
#              return_train_score=True, scoring='neg_mean_squared_error')

# %%
best_forest=grid_search.best_estimator_

# %%
best_forest.score(X_test_s,y_test)
# Out:
# 0.8261709309682512

# %%
grid_search.best_estimator_
# Out:
# RandomForestRegressor(n_estimators=300)

# %%
grid_search.best_estimator_.score(X_test_s, y_test)
# Out:
# 0.8261709309682512

# %%
from sklearn.neighbors import KNeighborsRegressor
knn_model = KNeighborsRegressor(n_neighbors=28)
knn_model.fit(X_train, y_train)
# Out:
# KNeighborsRegressor(n_neighbors=28)

# %%
y_predd = knn_model.predict(X_test)

# %%
X_test[:10]
# Out:
#        longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 12764    -121.40     38.61                33.0     8.164226        6.716595
# 2427     -119.49     36.58                21.0     7.653020        6.018593
# 1374     -122.12     38.01                50.0     7.170888        5.575949
# 4416     -118.26     34.08                50.0     7.491088        6.493754
# 2327     -119.71     36.81                19.0     7.407924        5.910797
# 15112    -116.98     32.86                19.0     7.660114        5.834811
# 3519     -118.49     34.25                33.0     7.644441        5.950643
# 66       -122.30     37.81                48.0     7.283448        5.872118
# 4829     -118.30     34.04                24.0     7.646354        6.373320
# 14009    -117.19     32.75                52.0     7.236339        5.365976
#
#        population  households  median_income  <1H OCEAN  INLAND  ISLAND  \
# 12764    7.323831    6.663133         1.9908      False    True   False
# 2427     6.766192    5.942799         1.9913      False    True   False
# 1374     6.539586    5.480639         3.9519      False   False   False
# 4416     7.688913    6.516193         1.7945       True   False   False
# 2327     6.324359    5.872118         1.7969      False    True   False
# 15112    7.120444    5.869297         4.7717       True   False   False
# 3519     6.867974    5.894403         4.3333       True   False   False
# 66       6.670766    5.808142         0.8056      False   False   False
# 4829     7.471932    6.289716         1.7109       True   False   False
# 14009    6.242223    5.356586         6.1309      False   False   False
#
#        NEAR BAY  NEAR OCEAN  bedroom_ratio  household_rooms
# 12764     False       False       0.822686         1.008024
# 2427      False       False       0.786434         1.012754
# 1374       True       False       0.777581         1.017390
# 4416      False       False       0.866864         0.996556
# 2327      False       False       0.797902         1.006587
# 15112     False       False       0.761713         0.994124
# 3519      False       False       0.778427         1.009541
# 66         True       False       0.806228         1.011015
# 4829      False       False       0.833511         1.013292
# 14009     False        True       0.741532         1.001753

# %%
y_predd[:10]
# Out:
# array([ 96485.71428571,  68550.        , 237239.32142857, 170932.14285714,
#         64214.28571429, 202817.85714286, 235096.46428571, 113625.        ,
#        186389.32142857, 396543.10714286])

# %%
knn_model.score(X_test, y_test)
# Out:
# 0.6852001171645001
